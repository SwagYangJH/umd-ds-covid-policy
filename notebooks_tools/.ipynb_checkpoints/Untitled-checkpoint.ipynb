# %%
# Setting Up Imports 

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager



import copy

from urllib.parse import urlparse
import numpy as np
import pandas as pd
import re 
from pathlib import Path
import os
import time
from datetime import date
from datetime import timedelta
from datetime import datetime
import dateutil.parser as parser

today = date.today()
cwd = os.getcwd()


# Setting up browser environment

userprofile = 'teamcovid'
options = webdriver.ChromeOptions()
options.add_argument(f"user-data-dir={cwd}/."+userprofile+"UserProfile")
driver = webdriver.Chrome(ChromeDriverManager().install() , options=options)
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [/Users/flipflops/.wdm/drivers/chromedriver/mac64/95.0.4638.54/chromedriver] found in cache
# /usr/local/Caskroom/miniconda/base/envs/tpc-wa/lib/python3.7/site-packages/ipykernel_launcher.py:37: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
src = 'https://data.census.gov/cedsci/profile?g=0400000US'

# %%
for i in range (1,30):
    
    
    MEDIAN_AGE = -1
    
    
    if len(str(i))==1:
        index_url = '0' + str(i)
    else:
        index_url = str(i)
            
    driver.get(src+index_url)
    
    time.sleep(2)
    noResList = driver.find_elements(By.XPATH,f"//h1[@class='{'message'}']")
    results = []
    for hits in noResList:
        results.append(hits.text)
    
    if ('No Results Found' in results):
        print('Not a valid url')
        print('---------\n\n')
        continue

    print('valid url')
#         //SCRAPE HERE 

    WebDriverWait(driver, 20).until(
    lambda driver : driver.find_element(By.XPATH,f"//h1[@class='{'profile-title'}']"))
    
    StateName = driver.find_element(By.XPATH,f"//h1[@class='{'profile-title'}']").text
    print(f'Found State, {StateName}')
    
    headerClass = 'aqua-layout highlight vertical align-center justify-center'
    headerList = driver.find_elements(By.XPATH,f"//div[@class='{headerClass}']")
    
    context = []
    value = [] 
    for header in headerList:

        all_children_by_xpath = header.find_elements(By.XPATH,".//*")
        for indice,headerInside in enumerate(all_children_by_xpath):
            textdata = headerInside.text
            if indice==2:
                context.append(textdata)
            if indice ==3:
                value.append(textdata)
            
            
    print(context)
    print(value)
    
    SHIT_METHOD_LIST = driver.find_elements(By.XPATH,f"//span[@class='{'measure-estimate-value'}']")
    for indice,dataElement in enumerate(SHIT_METHOD_LIST):
        if indice ==0:
            MEDIAN_AGE = dataElement.text
        print(indice,dataElement.text)
    
    
    print('---------\n\n')
# Out:
# valid url
# Found State, Alabama
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['5,024,279', '$51,734', '26.3%', '54.7%', '2,288,330', '9.7%', '100,731', '1,897,576', '264,047']
# ---------
#
#
# valid url
# Found State, Alaska
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['733,391', '$75,463', '30.2%', '59.3%', '326,200', '12.2%', '21,399', '252,199', '49,824']
# ---------
#
#
# Not a valid url
# ---------
#
#
# valid url
# Found State, Arizona
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['7,151,502', '$62,055', '30.2%', '56.8%', '3,082,000', '11.3%', '147,163', '2,670,441', '2,192,253']
# ---------
#
#
# valid url
# Found State, Arkansas
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['3,011,524', '$48,952', '23.3%', '55.2%', '1,365,265', '9.1%', '67,243', '1,163,647', '256,847']
# ---------
#
#
# valid url
# Found State, California
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['39,538,223', '$80,440', '35.0%', '60.3%', '14,392,140', '7.7%', '966,224', '13,157,873', '15,579,652']
# ---------
#
#
# Not a valid url
# ---------
#
#
# valid url
# Found State, Colorado
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['5,773,714', '$77,127', '42.7%', '65.3%', '2,491,404', '8.0%', '174,258', '2,235,103', '1,263,390']
# ---------
#
#
# valid url
# Found State, Connecticut
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['3,605,944', '$78,833', '39.8%', '62.3%', '1,530,197', '5.9%', '88,916', '1,377,166', '623,293']
# ---------
#
#
# valid url
# Found State, Delaware
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['989,948', '$70,176', '33.2%', '58.8%', '448,735', '6.6%', '26,142', '376,239', '104,290']
# ---------
#
#
# valid url
# Found State, District of Columbia
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['689,545', '$92,266', '59.7%', '66.0%', '350,364', '3.5%', '23,993', '291,570', '77,652']
# ---------
#
#
# valid url
# Found State, Florida
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['21,538,187', '$59,227', '30.7%', '56.2%', '9,865,350', '13.2%', '574,512', '7,905,832', '5,697,240']
# ---------
#
#
# valid url
# Found State, Georgia
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['10,711,908', '$61,980', '32.5%', '59.6%', '4,410,956', '13.4%', '239,034', '3,852,714', '1,123,457']
# ---------
#
#
# Not a valid url
# ---------
#
#
# valid url
# Found State, Hawaii
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['1,455,271', '$83,102', '33.6%', '58.5%', '561,066', '4.2%', '32,889', '465,299', '138,923']
# ---------
#
#
# valid url
# Found State, Idaho
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['1,839,106', '$60,999', '28.7%', '61.2%', '751,859', '10.8%', '50,547', '655,859', '239,407']
# ---------
#
#
# valid url
# Found State, Illinois
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['12,812,508', '$69,187', '35.8%', '61.7%', '5,426,429', '7.4%', '320,417', '4,866,006', '2,337,410']
# ---------
#
#
# valid url
# Found State, Indiana
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['6,785,528', '$57,603', '26.9%', '61.2%', '2,923,175', '8.7%', '148,917', '2,597,765', '554,191']
# ---------
#
#
# valid url
# Found State, Iowa
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['3,190,369', '$61,691', '29.3%', '64.3%', '1,412,789', '5.0%', '82,770', '1,287,221', '215,986']
# ---------
#
#
# valid url
# Found State, Kansas
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['2,937,880', '$62,087', '34.0%', '63.5%', '1,275,689', '9.2%', '74,292', '1,138,329', '382,603']
# ---------
#
#
# valid url
# Found State, Kentucky
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['4,505,836', '$52,295', '25.1%', '55.8%', '1,994,323', '6.4%', '91,219', '1,748,732', '207,854']
# ---------
#
#
# valid url
# Found State, Louisiana
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['4,657,757', '$51,073', '25.0%', '55.4%', '2,073,200', '8.9%', '106,302', '1,741,076', '322,549']
# ---------
#
#
# valid url
# Found State, Maine
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['1,362,359', '$58,924', '33.2%', '60.7%', '739,072', '8.0%', '41,843', '573,618', '26,609']
# ---------
#
#
# valid url
# Found State, Maryland
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['6,177,224', '$86,738', '40.9%', '63.7%', '2,530,844', '6.0%', '139,449', '2,226,767', '729,745']
# ---------
#
#
# valid url
# Found State, Massachusetts
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['7,029,917', '$85,843', '45.0%', '64.8%', '2,998,537', '3.0%', '181,061', '2,650,680', '887,685']
# ---------
# valid url
# Found State, Michigan
# []
# []
# ---------
#
#
# valid url
# Found State, Minnesota
# []
# []
# ---------
#
#
# valid url
# Found State, Mississippi
# []
# []
# ---------
#
#
# valid url
# Found State, Missouri
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['6,154,913', '$57,409', '30.2%', '59.8%', '2,786,621', '10.0%', '151,816', '2,458,337', '303,068']
# ---------

# %%
SHIT_METHOD_LIST = driver.find_elements(By.XPATH,f"//span[@class='{'measure-estimate-value'}']")

# %%
# Out:
# 0 38.9
# 1 38.5
# 2 3.1%
# 3 4.9%
# 4 15.0%
# 5 13.4%
# 6 6.6%
# 7 22.0%
# 8 4.3
# 9 13.7
# 10 17.2%
# 11 16.5%
# 12 2.5%
# 13 2.3%
# 14 8.1%
# 15 6.9%
# 16 $57,409
# 17 $65,712
# 18 12.9%
# 19 12.3%
# 20 30.2%
# 21 33.1%
# 22 68.8%
# 23 66.6%
# 24 12.7%
# 25 14.0%
# 26 24.3
# 27 27.6
# 28 59.8%
# 29 60.2%
# 30 13.7%
# 31 18.7%
# 32 28.8%
# 33 26.9%
# 34 38.9
# 35 38.8
# 36 $834
# 37 $1,097
# 38 2,786,621
# 39 140,498,736
# 40 2,479,146
# 41 126,817,580
# 42 29.0%
# 43 28.0%
# 44 21.6%
# 45 22.8%
# 46 307,475
# 47 13,681,156
# 48 14.7%
# 49 12.7%
# 50 1,400,522
# 51 76,879,571
# 52 10.0%
# 53 9.2%
# 54 $205,807
# 55 $47,500,246
# 56 $1,145,185
# 57 $400,465,610
# 58 22.4%
# 59 22.2%
# 60 3.04
# 61 3.23
# 62 30.7%
# 63 33.9%
# 64 30,518
# 65 3,727,135
# 66 133,377
# 67 19,886,049
# 68 699,840
# 69 41,104,200
# 70 303,068
# 71 62,080,044
# 72 9,730
# 73 689,966
# 74 4,663,907
# 75 191,697,647
# 76 127,942
# 77 27,915,715
# 78 413,171
# 79 33,848,943
# 80 4,740,335
# 81 204,277,273

# %%
medianState = driver.find_elements(By.XPATH,median_xpath)

# %%
medianState[2].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_8759/1823691086.py in <module>
# ----> 1 medianState[2].text
#
# IndexError: list index out of range

# %%
DATASTATS = ageStatsDiv[0].find_elements(By.XPATH,".//*")
for agedata in DATASTATS:
    print(agedata.text)

# %%
agedata.tag_name
# Out:
# 'div'

# %%
noResList = driver.find_elements(By.XPATH,f"//h1[@class='{'message'}']")

# %%
for hits in noResList:
    print(hits.text)
# Out:
# No Results Found

# %%
value
# Out:
# ['7,151,502',
#  '$62,055',
#  '30.2%',
#  '56.8%',
#  '3,082,000',
#  '11.3%',
#  '147,163',
#  '2,670,441',
#  '2,192,253']
